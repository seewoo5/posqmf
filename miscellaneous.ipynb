# %% [markdown]
# This file checks several miscellaneous claims in the thesis.

# %%
from posqmf import *
from tqdm import tqdm

# %% [markdown]
# ### Uniqueness of extremal quasimodular forms of higher depths
#
# The below code checks the uniqueness of extremal quasimodular forms of depth $5 \le s \le 10$ and weight $w \le 200$.

# %%
for s in range(5, 11):
    for w in tqdm(range(2 * s, 202, 2)):
        if w == 2 * s + 2:
            continue
        if not is_extremal_qm_unique(w, s):
            print(f"Extremal quasimodular form of weight {w} and depth {s} is NOT unique.")
# Out:
# 100%|██████████| 96/96 [00:29<00:00,  3.27it/s]
# 100%|██████████| 95/95 [00:37<00:00,  2.57it/s]
# 100%|██████████| 94/94 [00:50<00:00,  1.84it/s]
# 100%|██████████| 93/93 [01:06<00:00,  1.41it/s]
# 100%|██████████| 92/92 [01:29<00:00,  1.02it/s]
# 100%|██████████| 91/91 [02:00<00:00,  1.33s/it]

# %% [markdown]
# ### Complete positivity of extremal quasimodular forms of higher depths
#
# The below code find possible counterexamples to the naive extention of Kaneko--Koike conjecture for depth $s \ge 5$. For each $X_{w, s}$ with cusp order $m = m_{w, s}$, we only check coefficients up to $q^{2m}$.
# Hence it is possible that the "passed" cases may have negative coefficients at higher powers of $q$.

# %%
def check_all_positive(ls):
    # check if all the elements of a given list is positive
    # if there is a negative element, return it with index
    for i, x in enumerate(ls):
        if x < 0:
            return False, i, x
    return True, None, None 

for s in range(5, 11):
    for w in range(2 * s, 202, 2):
        if w == 2 * s + 2:
            continue
        X_w_s = extremal_qm(w, s)
        N = 2 * qm_cusp_order(X_w_s, 1000)
        check, i, x = check_all_positive(qm_coefficients(X_w_s, prec=N))
        if not check:
            print(f"X_{w},{s} is not completely positive: the {i}-th coefficient is {x} < 0.")
# Out:
# X_16,5 is not completely positive: the 8-th coefficient is -4809/16 < 0.
# X_32,5 is not completely positive: the 18-th coefficient is -238485597339535/325045522512 < 0.
# X_116,5 is not completely positive: the 60-th coefficient is - < 0.
# X_200,5 is not completely positive: the 102-th coefficient is -... < 0.
# X_20,6 is not completely positive: the 18-th coefficient is -257378238/26291 < 0.
# X_68,6 is not completely positive: the 40-th coefficient is -587808111354323280225458090587577921903609111806937442000779958239999983/142361144698359361498722456345459603111022443609536207404673963360784000 < 0.
# X_94,6 is not completely positive: the 56-th coefficient is - < 0.
# X_160,6 is not completely positive: the 150-th coefficient is -... < 0.
# X_186,6 is not completely positive: the 158-th coefficient is -... < 0.
# X_48,7 is not completely positive: the 31-th coefficient is -89157885279885661850722701306191115925072697448/3912624389017250726038160942606334665844767429 < 0.
# X_66,7 is not completely positive: the 49-th coefficient is -6019583625922081635004481289248557982200681197008016622532849485205235824855968055157463941256957228271557501476866032/3248896508848621529111919089431360700603037791459500535951483460271749035241518315772370638670451233046754845567 < 0.
# X_110,7 is not completely positive: the 73-th coefficient is -... < 0.
# X_150,7 is not completely positive: the 100-th coefficient is -... < 0.
# X_164,7 is not completely positive: the 111-th coefficient is -... < 0.
# X_168,7 is not completely positive: the 182-th coefficient is -... < 0.
# X_22,8 is not completely positive: the 17-th coefficient is -916220105379/2093495557 < 0.
# X_34,8 is not completely positive: the 25-th coefficient is -15909647689105305535202121379697/71309374589456536174196469907 < 0.
# X_54,8 is not completely positive: the 68-th coefficient is -4809807410160635644588249999474519718527113737129059478110964930280695024475152325675750599720104160095176/167036281813912246663079522629496617039935935125409227020881591681856739663471176222793211 < 0.
# X_64,8 is not completely positive: the 46-th coefficient is -27114532357291508899747564881108648964852026094645775872167792994985120707119030719538598290508183701328369284827015086097871795/25269795010207190270790344573691410337462220348427826563206571247122199444647578716667129291968714377169027284782731049727641 < 0.
# X_72,8 is not completely positive: the 62-th coefficient is - < 0.
# X_92,8 is not completely positive: the 68-th coefficient is -... < 0.
# X_134,8 is not completely positive: the 107-th coefficient is -... < 0.
# X_188,8 is not completely positive: the 145-th coefficient is -... < 0.
# X_198,8 is not completely positive: the 152-th coefficient is -... < 0.
# X_200,8 is not completely positive: the 153-th coefficient is -... < 0.
# X_18,9 is not completely positive: the 19-th coefficient is -28836525/2261 < 0.
# X_42,9 is not completely positive: the 32-th coefficient is -573240989096543402943600613698333398960856767280303128997/21466366222003905872901467384476133714039554549680398336 < 0.
# X_58,9 is not completely positive: the 46-th coefficient is -8697617511948121820671176839805341554202757668153712994589324266834694397676359013836557329366572240083435192387847484487313296/33904385937484596483692212964137025923968737652227519828550625243904099716910289194001010379282157990643661788450271745684375 < 0.
# X_114,9 is not completely positive: the 115-th coefficient is -... < 0.
# X_136,9 is not completely positive: the 111-th coefficient is -... < 0.
# X_150,9 is not completely positive: the 129-th coefficient is -... < 0.
# X_184,9 is not completely positive: the 178-th coefficient is -... < 0.
# X_32,10 is not completely positive: the 34-th coefficient is -450800513637537298207804204984388/297759588378360933034823265 < 0.
# X_34,10 is not completely positive: the 26-th coefficient is -808396737530668421370386112178461063/20095706101335263211178351379855812 < 0.
# X_76,10 is not completely positive: the 86-th coefficient is -... < 0.
# X_86,10 is not completely positive: the 77-th coefficient is -... < 0.
# X_134,10 is not completely positive: the 164-th coefficient is -... < 0.
# X_140,10 is not completely positive: the 148-th coefficient is -... < 0.
# X_182,10 is not completely positive: the 191-th coefficient is -... < 0.

# %% [markdown]
# $X_{16, 5}$ is the smallest counterexample, where all the coefficients except for the leading term are negative. This is proved by expressing it as a linear combination of derivatives of Eisenstein series and $\Delta E_4$ and $\Delta X_{4, 2}$, whose $q$-expansions can be easily bounded using the bounds for the divisor function $\sigma_k(n)$ and Ramanujan's tau function $\tau(n)$.

# %%
X_16_5 = extremal_qm(16, 5)
print_qm(X_16_5, "X_16,5", prec=100)

E8 = eisenstein(8)
E10 = eisenstein(10)
E12 = eisenstein(12)
E14 = eisenstein(14)
E16 = eisenstein(16)

X_4_2 = extremal_qm(4, 2)
DE14 = E14.derivative()
DDE12 = E12.derivative().derivative()
DDDE10 = E10.derivative().derivative().derivative()
DDDDE8 = E8.derivative().derivative().derivative().derivative()
DDDDDE6 = E6.derivative().derivative().derivative().derivative().derivative()

ls = [
